# %%
pip install -q rouge-score sentence-transformers pandas google-generativeai tqdm

# %%
import pandas as pd
import numpy as np
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer, util
import google.generativeai as genai
from tqdm import tqdm
import json
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/DS310/eval/eval_no_rewrite.csv')

# %%
data
# Out:
#                                              Question  \
# 0   Lộ trình áp dụng mức tiêu chuẩn khí thải đối v...
# 1   Trách nhiệm của Bộ Khoa học và Công nghệ trong...
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho nh...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Những ai đủ điều kiện để đăng ký dự tuyển vào ...
# 5   Xe thuần điện (PEV hoặc BEV) được định nghĩa n...
# 6   Xe hybrid điện (HEV) bao gồm những loại cụ thể...
# 7     Thế nào là phương tiện giao thông thông thường?
# 8   ấu hiệu nhận biết xe cơ giới sử dụng năng lượn...
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...
# 11  Hội đồng tuyển sinh có những nhiệm vụ và quyền...
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...
# 13  Những đối tượng nhà giáo, cán bộ quản lý nào đ...
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...
# 15  Mức phụ cấp ưu đãi dành cho nhà giáo tại các t...
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...
# 18  Sinh viên đại học trong nước ngành năng lượng ...
# 19  Quy định về việc ủy quyền đăng ký hộ tịch và c...
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...
# 21  Vị trí và tư cách pháp nhân của Đại học quốc g...
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con ba...
# 25  Các yêu cầu về chữ viết và mực in khi ghi Sổ h...
# 26  Hành vi xúc phạm danh dự, nhân phẩm của người ...
# 27  Nhà giáo công tác tại vùng có điều kiện kinh t...
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...
# 31  Sau khi tính toán và làm tròn, mức trợ cấp cụ ...
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...
# 33  Người khiếu nại có những quyền hạn gì trong qu...
# 34  Người lao động được hưởng chế độ bồi thường ta...
# 35  Hồ sơ bồi thường tai nạn lao động mà người sử ...
# 36  Cơ quan nào chịu trách nhiệm trực tiếp trong v...
# 37  Đối với những người nghỉ hưu trước năm 1995 có...
# 38  Thông tin về cung lao động và cầu lao động bao...
# 39  Thông tin về người lao động nước ngoài làm việ...
# 40  Sở Lao động - Thương binh và Xã hội có trách n...
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...
# 42  Quy định về việc nhận và gửi thư của phạm nhân...
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...
# 46  Cơ sở giam giữ áp dụng những hình thức nào để ...
# 47  Cán bộ, chiến sĩ ở cơ sở giam giữ bị nghiêm cấ...
# 48  Thế nào là hành vi "Tự nguyện giao nộp động vậ...
# 49  Để được thả lại về môi trường tự nhiên, động v...
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...
# 51  Những loại vũ khí, vật liệu nổ và công cụ hỗ t...
# 52  Việc xử lý đồ vật cấm là tiền Việt Nam, các lo...
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm nhữn...
#
#                                                Answer  \
# 0   Xe ô tô nhập khẩu mới và sản xuất, lắp ráp tiế...
# 1   Bộ Khoa học và Công nghệ Nghiên cứu, rà soát q...
# 2   Nhóm 3: Áp dụng với trường hợp khám sức khỏe đ...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Đối với trình độ cao đẳng: - Người có bằng tốt...
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...
# 7   Phương tiện giao thông thông thường là xe cơ g...
# 8   Dấu hiệu nhận biết xe cơ giới sử dụng năng lượ...
# 9   Đối với xe ô tô: Số người tối đa cho phép chở,...
# 10  a) Đăng ký trực tiếp trên Phiếu đăng ký dự tuy...
# 11  a) Tổ chức triển khai các phương án tuyển sinh...
# 12  2. Việc kiểm tra, đánh giá tình trạng an toàn ...
# 13  1. Nhà giáo, cán bộ quản lý giáo dục trong biê...
# 14  Người trực tiếp thực hiện kỹ thuật thụ tinh tr...
# 15  2. Mức phụ cấp 70% mức lương hiện hưởng và phụ...
# 16  Đại cương: thụ tinh trong ống nghiệm (IVF) là ...
# 17  Các cơ sở thực hiện thụ tinh trong ống nghiệm ...
# 18  a) Miễn học phí và ở ký túc xá miễn phí; b) Cấ...
# 19  Người yêu cầu cấp bản sao trích lục hộ tịch, c...
# 20  a) Cấp 02 vé máy bay khứ hồi hạng phổ thông đố...
# 21  1. Đại học quốc gia là cơ sở giáo dục đại học ...
# 22  Trường hợp việc đăng ký hộ tịch cần xác minh t...
# 23  Giấy xác nhận tình trạng hôn nhân có giá trị đ...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con th...
# 25  Nội dung ghi phải chính xác; chữ viết phải rõ ...
# 26  Phạt cảnh cáo hoặc phạt tiền từ 100.000 đồng đ...
# 27  1. Nhà giáo, cán bộ quản lý giáo dục (thuộc đị...
# 28  Giáo viên mầm non có thời gian làm việc trong ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  1. Tăng thêm 7,4% mức trợ cấp hằng tháng trên ...
# 31  a) Đối với cán bộ nguyên là Bí thư Đảng ủy, Ch...
# 32  1. Thời hiệu khiếu nại lần đầu là 180 ngày, kể...
# 33  a) Tự mình khiếu nại hoặc ủy quyền cho người k...
# 34  a) Người lao động bị tai nạn lao động làm suy ...
# 35  1. Đối với người lao động được hưởng chế độ bồ...
# 36  6. Bảo hiểm xã hội Việt Nam có trách nhiệm thự...
# 37  Tăng thêm 200.000 đồng/người/tháng đối với nhữ...
# 38  1. Thông tin, dữ liệu về cung lao động gồm thô...
# 39  a) Họ và tên; ngày, tháng, năm sinh; giới tính...
# 40  3. Sở Lao động - Thương binh và Xã hội chuyển ...
# 41  Thân nhân đến thăm gặp phạm nhân phải là người...
# 42  Phạm nhân được gửi 02 lá thư trong một tháng, ...
# 43  Thân nhân phạm nhân khi đến thăm gặp hoặc qua ...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  1. Tuân thủ Hiến pháp, pháp luật và quy định c...
# 46  Căn cứ đặc điểm, tính chất và nội dung phải cô...
# 47  6. Không tự ý tiếp xúc để lợi dụng vay, mượn, ...
# 48  5. Tự nguyện giao nộp động vật rừng cho Nhà nư...
# 49  2. Điều kiện: \n\na) Xác định được nơi cư trú ...
# 50  3. Cơ quan Kiểm lâm cấp huyện tổng hợp, định k...
# 51  1. Vũ khí quân dụng, súng săn, vũ khí thô sơ, ...
# 52  2. Đối với đồ vật cấm quy định tại khoản 7 Điề...
# 53  1. Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm:\...
#
#                                   Answer_from_chatbot
# 0   Dựa trên các đoạn thông tin được trích xuất, l...
# 1   Đoạn trích xuất không chứa thông tin để tôi tr...
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho cá...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Để đăng ký dự tuyển vào trình độ cao đẳng, nhữ...
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...
# 7   Phương tiện giao thông thông thường là xe cơ g...
# 8   Để nhận biết xe cơ giới sử dụng năng lượng sạc...
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...
# 11  Dựa trên các đoạn thông tin được trích xuất, H...
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...
# 13  Nghị định này điều chỉnh các đối tượng nhà giá...
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...
# 15  Dựa trên các đoạn thông tin được trích xuất:\n...
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...
# 18  Sinh viên đại học trong nước theo học ngành nă...
# 19  Đoạn trích xuất không chứa thông tin để tôi tr...
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...
# 21  Dựa trên các đoạn thông tin được trích xuất, v...
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...
# 24  Để chứng minh quan hệ cha, mẹ, con, các loại g...
# 25  Dựa trên các đoạn thông tin được trích xuất, c...
# 26  Dựa trên các đoạn thông tin được trích xuất, h...
# 27  Dựa trên các đoạn thông tin được trích xuất, n...
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...
# 31  Dựa trên thông tin được trích xuất, mức trợ cấ...
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...
# 33  Người khiếu nại có các quyền hạn sau đây trong...
# 34  Người lao động được hưởng chế độ bồi thường ta...
# 35  Người sử dụng lao động có trách nhiệm lập hồ s...
# 36  Dựa trên các đoạn thông tin được trích xuất:\n...
# 37  Đối với những người nghỉ hưu trước năm 1995 có...
# 38  Thông tin về cung lao động và cầu lao động bao...
# 39  Đoạn trích xuất không chứa thông tin để tôi tr...
# 40  Dựa trên các đoạn thông tin được trích xuất, S...
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...
# 42  Dưới đây là tổng hợp quy định về việc nhận và ...
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...
# 46  Dựa trên thông tin được trích xuất, cơ sở giam...
# 47  Đoạn trích xuất không chứa thông tin để tôi tr...
# 48  Hành vi "Tự nguyện giao nộp động vật rừng cho ...
# 49  Để được thả lại về môi trường tự nhiên, động v...
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...
# 51  Đoạn trích xuất không chứa thông tin để tôi tr...
# 52  Dựa trên các đoạn thông tin được trích xuất, v...
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm các ...

# %%
EMBED_MODEL = "bkai-foundation-models/vietnamese-bi-encoder"

GOOGLE_API_KEY = ""
genai.configure(api_key=GOOGLE_API_KEY)
judge_model = genai.GenerativeModel('gemini-2.5-flash')

# %%
class RAGEvaluator:
    def __init__(self):
        self.embedder = SentenceTransformer(EMBED_MODEL)
        self.rouge_scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=False)

    def calculate_scores(self, row):
        ques = str(row['Question'])
        ref = str(row['Answer'])              # Câu trả lời chuẩn (Ground Truth)
        gen = str(row['Answer_from_chatbot']) # Câu trả lời của bot

        rouge_score = self.rouge_scorer.score(ref, gen)['rougeL'].fmeasure

        emb1 = self.embedder.encode(gen, convert_to_tensor=True)
        emb2 = self.embedder.encode(ref, convert_to_tensor=True)
        semantic_score = util.cos_sim(emb1, emb2).item()

        return pd.Series({
            'rouge_l': rouge_score,
            'semantic_score': semantic_score
        })

    def evaluate_dataset(self, df):
        print(f" Đang đánh giá {len(df)} câu hỏi...")
        tqdm.pandas() # Hiện thanh progress bar

        # Áp dụng hàm tính toán cho từng dòng (axis=1)
        results = df.progress_apply(self.calculate_scores, axis=1)

        # Nối kết quả vào bảng gốc
        final_df = pd.concat([df, results], axis=1)
        return final_df

# %%
def call_gemini_batch(judge_model, batch_df):
        """Tạo prompt chứa nhiều câu hỏi một lúc"""

        # 1. Tạo chuỗi JSON input
        items = []
        for idx, row in batch_df.iterrows():
            items.append({
                "id": idx, # Giữ ID để dễ tracking
                "question": str(row['Question']),
                "ground_truth": str(row['Answer']),
                "ai_answer": str(row['Answer_from_chatbot'])
            })

        prompt = f"""
        Bạn là giám khảo chấm điểm hệ thống RAG pháp lý.
        Dưới đây là danh sách {len(items)} cặp câu hỏi - trả lời.

        INPUT DATA (JSON):
        {json.dumps(items, ensure_ascii=False)}
        Hãy chấm điểm câu trả lời do chatobt tạo và câu trả lời ground_truth trên thang 1 đến 5, điểm có thể là 3.4, 4.4, không nhất thiết phải là số nguyên dựa trên các tiêu chí:
        1. Tính chính xác về thông tin pháp lý.
        2. Sự đầy đủ so với câu trả lời chuẩn.
        3. Không bịa đặt thông tin.
        4. Hãy so sánh cả về độ đúng trọng tâm, nếu câu trả lời ngắn nhưng đúng trọng tâm thì điểm càng cao
        5. Thứ tự điểm số phải tương ứng chính xác với thứ tự Input.
        6. KHÔNG giải thích, KHÔNG markdown code block, chỉ list số.
        7. Output mẫu: [4.7, 4.3, 3, 5, 1.4]
        """

        try:
            # Gọi API
            response = judge_model.generate_content(prompt)
            text_resp = response.text.strip()

            # Xử lý làm sạch chuỗi nếu model trả về ```json [1,2,3] ```
            text_resp = text_resp.replace("```json", "").replace("```", "").strip()

            # Parse JSON
            scores = json.loads(text_resp)

            # Đảm bảo output là list các số int
            if isinstance(scores, list):
                return scores
            else:
                return [0] * len(items)
        except Exception as e:
            print(f" Lỗi Batch: {e}")
            # Trả về list 0 nếu lỗi
            return [0] * len(items)

# %%
# 2. Khởi chạy
evaluator = RAGEvaluator()
df_results = evaluator.evaluate_dataset(data)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
#  Đang đánh giá 54 câu hỏi...
# 100%|██████████| 54/54 [01:14<00:00,  1.37s/it]

# %%
df_results
# Out:
#                                              Question  \
# 0   Lộ trình áp dụng mức tiêu chuẩn khí thải đối v...
# 1   Trách nhiệm của Bộ Khoa học và Công nghệ trong...
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho nh...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Những ai đủ điều kiện để đăng ký dự tuyển vào ...
# 5   Xe thuần điện (PEV hoặc BEV) được định nghĩa n...
# 6   Xe hybrid điện (HEV) bao gồm những loại cụ thể...
# 7     Thế nào là phương tiện giao thông thông thường?
# 8   ấu hiệu nhận biết xe cơ giới sử dụng năng lượn...
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...
# 11  Hội đồng tuyển sinh có những nhiệm vụ và quyền...
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...
# 13  Những đối tượng nhà giáo, cán bộ quản lý nào đ...
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...
# 15  Mức phụ cấp ưu đãi dành cho nhà giáo tại các t...
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...
# 18  Sinh viên đại học trong nước ngành năng lượng ...
# 19  Quy định về việc ủy quyền đăng ký hộ tịch và c...
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...
# 21  Vị trí và tư cách pháp nhân của Đại học quốc g...
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con ba...
# 25  Các yêu cầu về chữ viết và mực in khi ghi Sổ h...
# 26  Hành vi xúc phạm danh dự, nhân phẩm của người ...
# 27  Nhà giáo công tác tại vùng có điều kiện kinh t...
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...
# 31  Sau khi tính toán và làm tròn, mức trợ cấp cụ ...
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...
# 33  Người khiếu nại có những quyền hạn gì trong qu...
# 34  Người lao động được hưởng chế độ bồi thường ta...
# 35  Hồ sơ bồi thường tai nạn lao động mà người sử ...
# 36  Cơ quan nào chịu trách nhiệm trực tiếp trong v...
# 37  Đối với những người nghỉ hưu trước năm 1995 có...
# 38  Thông tin về cung lao động và cầu lao động bao...
# 39  Thông tin về người lao động nước ngoài làm việ...
# 40  Sở Lao động - Thương binh và Xã hội có trách n...
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...
# 42  Quy định về việc nhận và gửi thư của phạm nhân...
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...
# 46  Cơ sở giam giữ áp dụng những hình thức nào để ...
# 47  Cán bộ, chiến sĩ ở cơ sở giam giữ bị nghiêm cấ...
# 48  Thế nào là hành vi "Tự nguyện giao nộp động vậ...
# 49  Để được thả lại về môi trường tự nhiên, động v...
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...
# 51  Những loại vũ khí, vật liệu nổ và công cụ hỗ t...
# 52  Việc xử lý đồ vật cấm là tiền Việt Nam, các lo...
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm nhữn...
#
#                                                Answer  \
# 0   Xe ô tô nhập khẩu mới và sản xuất, lắp ráp tiế...
# 1   Bộ Khoa học và Công nghệ Nghiên cứu, rà soát q...
# 2   Nhóm 3: Áp dụng với trường hợp khám sức khỏe đ...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Đối với trình độ cao đẳng: - Người có bằng tốt...
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...
# 7   Phương tiện giao thông thông thường là xe cơ g...
# 8   Dấu hiệu nhận biết xe cơ giới sử dụng năng lượ...
# 9   Đối với xe ô tô: Số người tối đa cho phép chở,...
# 10  a) Đăng ký trực tiếp trên Phiếu đăng ký dự tuy...
# 11  a) Tổ chức triển khai các phương án tuyển sinh...
# 12  2. Việc kiểm tra, đánh giá tình trạng an toàn ...
# 13  1. Nhà giáo, cán bộ quản lý giáo dục trong biê...
# 14  Người trực tiếp thực hiện kỹ thuật thụ tinh tr...
# 15  2. Mức phụ cấp 70% mức lương hiện hưởng và phụ...
# 16  Đại cương: thụ tinh trong ống nghiệm (IVF) là ...
# 17  Các cơ sở thực hiện thụ tinh trong ống nghiệm ...
# 18  a) Miễn học phí và ở ký túc xá miễn phí; b) Cấ...
# 19  Người yêu cầu cấp bản sao trích lục hộ tịch, c...
# 20  a) Cấp 02 vé máy bay khứ hồi hạng phổ thông đố...
# 21  1. Đại học quốc gia là cơ sở giáo dục đại học ...
# 22  Trường hợp việc đăng ký hộ tịch cần xác minh t...
# 23  Giấy xác nhận tình trạng hôn nhân có giá trị đ...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con th...
# 25  Nội dung ghi phải chính xác; chữ viết phải rõ ...
# 26  Phạt cảnh cáo hoặc phạt tiền từ 100.000 đồng đ...
# 27  1. Nhà giáo, cán bộ quản lý giáo dục (thuộc đị...
# 28  Giáo viên mầm non có thời gian làm việc trong ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  1. Tăng thêm 7,4% mức trợ cấp hằng tháng trên ...
# 31  a) Đối với cán bộ nguyên là Bí thư Đảng ủy, Ch...
# 32  1. Thời hiệu khiếu nại lần đầu là 180 ngày, kể...
# 33  a) Tự mình khiếu nại hoặc ủy quyền cho người k...
# 34  a) Người lao động bị tai nạn lao động làm suy ...
# 35  1. Đối với người lao động được hưởng chế độ bồ...
# 36  6. Bảo hiểm xã hội Việt Nam có trách nhiệm thự...
# 37  Tăng thêm 200.000 đồng/người/tháng đối với nhữ...
# 38  1. Thông tin, dữ liệu về cung lao động gồm thô...
# 39  a) Họ và tên; ngày, tháng, năm sinh; giới tính...
# 40  3. Sở Lao động - Thương binh và Xã hội chuyển ...
# 41  Thân nhân đến thăm gặp phạm nhân phải là người...
# 42  Phạm nhân được gửi 02 lá thư trong một tháng, ...
# 43  Thân nhân phạm nhân khi đến thăm gặp hoặc qua ...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  1. Tuân thủ Hiến pháp, pháp luật và quy định c...
# 46  Căn cứ đặc điểm, tính chất và nội dung phải cô...
# 47  6. Không tự ý tiếp xúc để lợi dụng vay, mượn, ...
# 48  5. Tự nguyện giao nộp động vật rừng cho Nhà nư...
# 49  2. Điều kiện: \n\na) Xác định được nơi cư trú ...
# 50  3. Cơ quan Kiểm lâm cấp huyện tổng hợp, định k...
# 51  1. Vũ khí quân dụng, súng săn, vũ khí thô sơ, ...
# 52  2. Đối với đồ vật cấm quy định tại khoản 7 Điề...
# 53  1. Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm:\...
#
#                                   Answer_from_chatbot   rouge_l  \
# 0   Dựa trên các đoạn thông tin được trích xuất, l...  0.097606
# 1   Đoạn trích xuất không chứa thông tin để tôi tr...  0.148936
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho cá...  0.835165
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...  0.637143
# 4   Để đăng ký dự tuyển vào trình độ cao đẳng, nhữ...  0.299233
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...  1.000000
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...  0.836090
# 7   Phương tiện giao thông thông thường là xe cơ g...  1.000000
# 8   Để nhận biết xe cơ giới sử dụng năng lượng sạc...  0.449799
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...  0.515060
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...  0.491979
# 11  Dựa trên các đoạn thông tin được trích xuất, H...  0.875000
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...  0.968153
# 13  Nghị định này điều chỉnh các đối tượng nhà giá...  0.250000
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...  0.564374
# 15  Dựa trên các đoạn thông tin được trích xuất:\n...  0.210256
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...  0.348718
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...  0.411765
# 18  Sinh viên đại học trong nước theo học ngành nă...  0.299850
# 19  Đoạn trích xuất không chứa thông tin để tôi tr...  0.101449
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...  0.271845
# 21  Dựa trên các đoạn thông tin được trích xuất, v...  0.441558
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...  0.403171
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...  0.142119
# 24  Để chứng minh quan hệ cha, mẹ, con, các loại g...  0.543524
# 25  Dựa trên các đoạn thông tin được trích xuất, c...  0.607242
# 26  Dựa trên các đoạn thông tin được trích xuất, h...  0.185609
# 27  Dựa trên các đoạn thông tin được trích xuất, n...  0.204120
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...  0.486631
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...  0.731377
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...  0.261993
# 31  Dựa trên thông tin được trích xuất, mức trợ cấ...  0.599327
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...  0.417417
# 33  Người khiếu nại có các quyền hạn sau đây trong...  0.230230
# 34  Người lao động được hưởng chế độ bồi thường ta...  0.190715
# 35  Người sử dụng lao động có trách nhiệm lập hồ s...  0.284953
# 36  Dựa trên các đoạn thông tin được trích xuất:\n...  0.313402
# 37  Đối với những người nghỉ hưu trước năm 1995 có...  0.283951
# 38  Thông tin về cung lao động và cầu lao động bao...  0.902985
# 39  Đoạn trích xuất không chứa thông tin để tôi tr...  0.169231
# 40  Dựa trên các đoạn thông tin được trích xuất, S...  0.246225
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...  0.419552
# 42  Dưới đây là tổng hợp quy định về việc nhận và ...  0.233962
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...  0.526829
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...  0.354545
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...  0.359848
# 46  Dựa trên thông tin được trích xuất, cơ sở giam...  0.517647
# 47  Đoạn trích xuất không chứa thông tin để tôi tr...  0.085938
# 48  Hành vi "Tự nguyện giao nộp động vật rừng cho ...  0.287611
# 49  Để được thả lại về môi trường tự nhiên, động v...  0.887949
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...  0.281392
# 51  Đoạn trích xuất không chứa thông tin để tôi tr...  0.099099
# 52  Dựa trên các đoạn thông tin được trích xuất, v...  0.143328
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm các ...  0.935223
#
#     semantic_score
# 0         0.804243
# 1         0.040849
# 2         0.823402
# 3         0.842173
# 4         0.728039
# 5         0.991718
# 6         0.947159
# 7         1.000000
# 8         0.780287
# 9         0.834515
# 10        0.759103
# 11        0.710836
# 12        0.925265
# 13        0.821293
# 14        0.882586
# 15        0.545607
# 16        0.720303
# 17        0.673233
# 18        0.346439
# 19        0.126384
# 20        0.356136
# 21        0.756690
# 22        0.828036
# 23        0.809555
# 24        0.834628
# 25        0.767246
# 26        0.553634
# 27        0.607390
# 28        0.781178
# 29        0.969434
# 30        0.662455
# 31        0.781549
# 32        0.863142
# 33        0.717023
# 34        0.456169
# 35        0.834050
# 36        0.734451
# 37        0.278845
# 38        0.890687
# 39       -0.068985
# 40        0.847049
# 41        0.863857
# 42        0.731233
# 43        0.673045
# 44        0.746107
# 45        0.552122
# 46        0.726398
# 47        0.162400
# 48        0.806198
# 49        0.822228
# 50        0.793706
# 51       -0.045091
# 52        0.424544
# 53        0.938645

# %%
BATCH_SIZE = 10
total_rows = len(data)
all_scores = []
print(f"\n Bắt đầu gọi API chấm điểm (Batch Size = {BATCH_SIZE})...")

for i in tqdm(range(0, total_rows, BATCH_SIZE)):
  batch_df = df_results.iloc[i : i + BATCH_SIZE]
  batch_scores = call_gemini_batch(judge_model,batch_df)

  if len(batch_scores) != len(batch_df):
    print(f"Batch {i} gửi {len(batch_df)} dòng nhưng nhận {len(batch_scores)} điểm. Fill 0 cho an toàn.")
    batch_scores = [0] * len(batch_df)

  all_scores.extend(batch_scores)

  # Ngủ để tránh bị Google chặn vì spam request quá nhanh
  time.sleep(60)

df_results['llm_score'] = all_scores
# Out:
#  Bắt đầu gọi API chấm điểm (Batch Size = 10)...
# 100%|██████████| 6/6 [09:32<00:00, 95.39s/it]

# %%
print("\n=== KẾT QUẢ ĐÁNH GIÁ TRUNG BÌNH ===")
print(f"ROUGE-L (Cấu trúc): {df_results['rouge_l'].mean():.4f}")
print(f"Semantic (Ngữ nghĩa): {df_results['semantic_score'].mean():.4f}")
print(f"LLM Score: {df_results['llm_score'].mean():.4f}")
# Out:
# === KẾT QUẢ ĐÁNH GIÁ TRUNG BÌNH ===
# ROUGE-L (Cấu trúc): 0.4332
# Semantic (Ngữ nghĩa): 0.6807
# LLM Score: 3.3944

# %%
df_results
# Out:
#                                              Question  \
# 0   Lộ trình áp dụng mức tiêu chuẩn khí thải đối v...
# 1   Trách nhiệm của Bộ Khoa học và Công nghệ trong...
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho nh...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Những ai đủ điều kiện để đăng ký dự tuyển vào ...
# 5   Xe thuần điện (PEV hoặc BEV) được định nghĩa n...
# 6   Xe hybrid điện (HEV) bao gồm những loại cụ thể...
# 7     Thế nào là phương tiện giao thông thông thường?
# 8   ấu hiệu nhận biết xe cơ giới sử dụng năng lượn...
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...
# 11  Hội đồng tuyển sinh có những nhiệm vụ và quyền...
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...
# 13  Những đối tượng nhà giáo, cán bộ quản lý nào đ...
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...
# 15  Mức phụ cấp ưu đãi dành cho nhà giáo tại các t...
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...
# 18  Sinh viên đại học trong nước ngành năng lượng ...
# 19  Quy định về việc ủy quyền đăng ký hộ tịch và c...
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...
# 21  Vị trí và tư cách pháp nhân của Đại học quốc g...
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con ba...
# 25  Các yêu cầu về chữ viết và mực in khi ghi Sổ h...
# 26  Hành vi xúc phạm danh dự, nhân phẩm của người ...
# 27  Nhà giáo công tác tại vùng có điều kiện kinh t...
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...
# 31  Sau khi tính toán và làm tròn, mức trợ cấp cụ ...
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...
# 33  Người khiếu nại có những quyền hạn gì trong qu...
# 34  Người lao động được hưởng chế độ bồi thường ta...
# 35  Hồ sơ bồi thường tai nạn lao động mà người sử ...
# 36  Cơ quan nào chịu trách nhiệm trực tiếp trong v...
# 37  Đối với những người nghỉ hưu trước năm 1995 có...
# 38  Thông tin về cung lao động và cầu lao động bao...
# 39  Thông tin về người lao động nước ngoài làm việ...
# 40  Sở Lao động - Thương binh và Xã hội có trách n...
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...
# 42  Quy định về việc nhận và gửi thư của phạm nhân...
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...
# 46  Cơ sở giam giữ áp dụng những hình thức nào để ...
# 47  Cán bộ, chiến sĩ ở cơ sở giam giữ bị nghiêm cấ...
# 48  Thế nào là hành vi "Tự nguyện giao nộp động vậ...
# 49  Để được thả lại về môi trường tự nhiên, động v...
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...
# 51  Những loại vũ khí, vật liệu nổ và công cụ hỗ t...
# 52  Việc xử lý đồ vật cấm là tiền Việt Nam, các lo...
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm nhữn...
#
#                                                Answer  \
# 0   Xe ô tô nhập khẩu mới và sản xuất, lắp ráp tiế...
# 1   Bộ Khoa học và Công nghệ Nghiên cứu, rà soát q...
# 2   Nhóm 3: Áp dụng với trường hợp khám sức khỏe đ...
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...
# 4   Đối với trình độ cao đẳng: - Người có bằng tốt...
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...
# 7   Phương tiện giao thông thông thường là xe cơ g...
# 8   Dấu hiệu nhận biết xe cơ giới sử dụng năng lượ...
# 9   Đối với xe ô tô: Số người tối đa cho phép chở,...
# 10  a) Đăng ký trực tiếp trên Phiếu đăng ký dự tuy...
# 11  a) Tổ chức triển khai các phương án tuyển sinh...
# 12  2. Việc kiểm tra, đánh giá tình trạng an toàn ...
# 13  1. Nhà giáo, cán bộ quản lý giáo dục trong biê...
# 14  Người trực tiếp thực hiện kỹ thuật thụ tinh tr...
# 15  2. Mức phụ cấp 70% mức lương hiện hưởng và phụ...
# 16  Đại cương: thụ tinh trong ống nghiệm (IVF) là ...
# 17  Các cơ sở thực hiện thụ tinh trong ống nghiệm ...
# 18  a) Miễn học phí và ở ký túc xá miễn phí; b) Cấ...
# 19  Người yêu cầu cấp bản sao trích lục hộ tịch, c...
# 20  a) Cấp 02 vé máy bay khứ hồi hạng phổ thông đố...
# 21  1. Đại học quốc gia là cơ sở giáo dục đại học ...
# 22  Trường hợp việc đăng ký hộ tịch cần xác minh t...
# 23  Giấy xác nhận tình trạng hôn nhân có giá trị đ...
# 24  Chứng cứ để chứng minh quan hệ cha, mẹ, con th...
# 25  Nội dung ghi phải chính xác; chữ viết phải rõ ...
# 26  Phạt cảnh cáo hoặc phạt tiền từ 100.000 đồng đ...
# 27  1. Nhà giáo, cán bộ quản lý giáo dục (thuộc đị...
# 28  Giáo viên mầm non có thời gian làm việc trong ...
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...
# 30  1. Tăng thêm 7,4% mức trợ cấp hằng tháng trên ...
# 31  a) Đối với cán bộ nguyên là Bí thư Đảng ủy, Ch...
# 32  1. Thời hiệu khiếu nại lần đầu là 180 ngày, kể...
# 33  a) Tự mình khiếu nại hoặc ủy quyền cho người k...
# 34  a) Người lao động bị tai nạn lao động làm suy ...
# 35  1. Đối với người lao động được hưởng chế độ bồ...
# 36  6. Bảo hiểm xã hội Việt Nam có trách nhiệm thự...
# 37  Tăng thêm 200.000 đồng/người/tháng đối với nhữ...
# 38  1. Thông tin, dữ liệu về cung lao động gồm thô...
# 39  a) Họ và tên; ngày, tháng, năm sinh; giới tính...
# 40  3. Sở Lao động - Thương binh và Xã hội chuyển ...
# 41  Thân nhân đến thăm gặp phạm nhân phải là người...
# 42  Phạm nhân được gửi 02 lá thư trong một tháng, ...
# 43  Thân nhân phạm nhân khi đến thăm gặp hoặc qua ...
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...
# 45  1. Tuân thủ Hiến pháp, pháp luật và quy định c...
# 46  Căn cứ đặc điểm, tính chất và nội dung phải cô...
# 47  6. Không tự ý tiếp xúc để lợi dụng vay, mượn, ...
# 48  5. Tự nguyện giao nộp động vật rừng cho Nhà nư...
# 49  2. Điều kiện: \n\na) Xác định được nơi cư trú ...
# 50  3. Cơ quan Kiểm lâm cấp huyện tổng hợp, định k...
# 51  1. Vũ khí quân dụng, súng săn, vũ khí thô sơ, ...
# 52  2. Đối với đồ vật cấm quy định tại khoản 7 Điề...
# 53  1. Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm:\...
#
#                                   Answer_from_chatbot   rouge_l  \
# 0   Dựa trên các đoạn thông tin được trích xuất, l...  0.097606
# 1   Đoạn trích xuất không chứa thông tin để tôi tr...  0.148936
# 2   Tiêu chuẩn sức khỏe Nhóm 3 được áp dụng cho cá...  0.835165
# 3   Cấu trúc dữ liệu kết quả khám sức khỏe của ngư...  0.637143
# 4   Để đăng ký dự tuyển vào trình độ cao đẳng, nhữ...  0.299233
# 5   Xe thuần điện (PEV - Pure electric vehicle hoặ...  1.000000
# 6   Xe hybrid điện (HEV - Hybrid electric vehicle)...  0.836090
# 7   Phương tiện giao thông thông thường là xe cơ g...  1.000000
# 8   Để nhận biết xe cơ giới sử dụng năng lượng sạc...  0.449799
# 9   Số người tối đa cho phép chở trên mỗi loại xe ...  0.515060
# 10  Thí sinh có thể nộp hồ sơ đăng ký dự tuyển thô...  0.491979
# 11  Dựa trên các đoạn thông tin được trích xuất, H...  0.875000
# 12  Việc kiểm tra, đánh giá tình trạng an toàn kỹ ...  0.968153
# 13  Nghị định này điều chỉnh các đối tượng nhà giá...  0.250000
# 14  Nhân sự trực tiếp thực hiện kỹ thuật thụ tinh ...  0.564374
# 15  Dựa trên các đoạn thông tin được trích xuất:\n...  0.210256
# 16  Kỹ thuật thụ tinh trong ống nghiệm (IVF) được ...  0.348718
# 17  Thời gian lưu giữ thông tin, dữ liệu đối với c...  0.411765
# 18  Sinh viên đại học trong nước theo học ngành nă...  0.299850
# 19  Đoạn trích xuất không chứa thông tin để tôi tr...  0.101449
# 20  Chế độ hỗ trợ đi lại và sinh hoạt phí cho ngườ...  0.271845
# 21  Dựa trên các đoạn thông tin được trích xuất, v...  0.441558
# 22  Khi đăng ký hộ tịch cần xác minh mà không nhận...  0.403171
# 23  Giá trị sử dụng của Giấy xác nhận tình trạng h...  0.142119
# 24  Để chứng minh quan hệ cha, mẹ, con, các loại g...  0.543524
# 25  Dựa trên các đoạn thông tin được trích xuất, c...  0.607242
# 26  Dựa trên các đoạn thông tin được trích xuất, h...  0.185609
# 27  Dựa trên các đoạn thông tin được trích xuất, n...  0.204120
# 28  Chính sách hỗ trợ riêng cho giáo viên mầm non ...  0.486631
# 29  Biện pháp cấm tiếp xúc với nạn nhân bạo lực gi...  0.731377
# 30  Công thức và tỷ lệ điều chỉnh mức trợ cấp hằng...  0.261993
# 31  Dựa trên thông tin được trích xuất, mức trợ cấ...  0.599327
# 32  Thời hiệu thực hiện khiếu nại lần đầu được quy...  0.417417
# 33  Người khiếu nại có các quyền hạn sau đây trong...  0.230230
# 34  Người lao động được hưởng chế độ bồi thường ta...  0.190715
# 35  Người sử dụng lao động có trách nhiệm lập hồ s...  0.284953
# 36  Dựa trên các đoạn thông tin được trích xuất:\n...  0.313402
# 37  Đối với những người nghỉ hưu trước năm 1995 có...  0.283951
# 38  Thông tin về cung lao động và cầu lao động bao...  0.902985
# 39  Đoạn trích xuất không chứa thông tin để tôi tr...  0.169231
# 40  Dựa trên các đoạn thông tin được trích xuất, S...  0.246225
# 41  Thủ tục đối với thân nhân đến thăm gặp phạm nh...  0.419552
# 42  Dưới đây là tổng hợp quy định về việc nhận và ...  0.233962
# 43  Thuốc chữa bệnh do thân nhân gửi cho phạm nhân...  0.526829
# 44  Khi liên lạc điện thoại với thân nhân, phạm nh...  0.354545
# 45  Các nguyên tắc thực hiện dân chủ trong tạm giữ...  0.359848
# 46  Dựa trên thông tin được trích xuất, cơ sở giam...  0.517647
# 47  Đoạn trích xuất không chứa thông tin để tôi tr...  0.085938
# 48  Hành vi "Tự nguyện giao nộp động vật rừng cho ...  0.287611
# 49  Để được thả lại về môi trường tự nhiên, động v...  0.887949
# 50  Trách nhiệm báo cáo kết quả tiếp nhận, xử lý đ...  0.281392
# 51  Đoạn trích xuất không chứa thông tin để tôi tr...  0.099099
# 52  Dựa trên các đoạn thông tin được trích xuất, v...  0.143328
# 53  Hồ sơ xử lý đồ vật cấm bị thu giữ bao gồm các ...  0.935223
#
#     semantic_score  llm_score
# 0         0.804243        3.0
# 1         0.040849        1.0
# 2         0.823402        5.0
# 3         0.842173        2.0
# 4         0.728039        4.0
# 5         0.991718        5.0
# 6         0.947159        4.8
# 7         1.000000        5.0
# 8         0.780287        3.5
# 9         0.834515        4.5
# 10        0.759103        2.5
# 11        0.710836        5.0
# 12        0.925265        5.0
# 13        0.821293        3.5
# 14        0.882586        3.0
# 15        0.545607        1.0
# 16        0.720303        4.0
# 17        0.673233        4.8
# 18        0.346439        4.9
# 19        0.126384        1.0
# 20        0.356136        0.0
# 21        0.756690        0.0
# 22        0.828036        0.0
# 23        0.809555        0.0
# 24        0.834628        0.0
# 25        0.767246        0.0
# 26        0.553634        0.0
# 27        0.607390        0.0
# 28        0.781178        0.0
# 29        0.969434        0.0
# 30        0.662455        4.5
# 31        0.781549        4.8
# 32        0.863142        3.5
# 33        0.717023        4.9
# 34        0.456169        1.5
# 35        0.834050        2.5
# 36        0.734451        3.8
# 37        0.278845        1.0
# 38        0.890687        5.0
# 39       -0.068985        1.0
# 40        0.847049        3.8
# 41        0.863857        3.5
# 42        0.731233        4.5
# 43        0.673045        5.0
# 44        0.746107        3.0
# 45        0.552122        1.0
# 46        0.726398        1.5
# 47        0.162400        1.0
# 48        0.806198        4.0
# 49        0.822228        4.8
# 50        0.793706        4.8
# 51       -0.045091        1.0
# 52        0.424544        2.0
# 53        0.938645        5.0

# %%
df_results.to_csv("ket_qua_danh_gia.csv", index=False)
