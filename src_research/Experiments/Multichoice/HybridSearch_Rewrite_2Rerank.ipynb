# %%
import sys
import os
import pandas as pd
from tqdm import tqdm

# Khai báo đường dẫn module
module_path = "/kaggle/input/datasets/tihunhpht/se365-gte-bge-v2/module"
# if module_path not in sys.path:
#     sys.path.append(module_path)

os.chdir(module_path)

# %%
# !ls
# Out:
# config			  gen_ansText_qwen_3B.py  retrieval_hybrid.py
# data			  gen_ansText_qwen_7B.py  rewrite_qwen_3B.py
# database		  hybrid_search.py	  rewrite_qwen_7B.py
# dense_search.py		  pipeline_choose.py	  rrf.py
# desktop.ini		  pipeline.py		  setup.py
# extract.py		  requirements.txt	  sparse_search.py
# gen_ansChoose_qwen_3B.py  rerank.py

# %%
# !pip install -r requirements.txt
# Out:
# Collecting qdrant-client==1.18.0 (from -r requirements.txt (line 1))
#   Downloading qdrant_client-1.18.0-py3-none-any.whl.metadata (11 kB)
# Collecting pyvi==0.1.1 (from -r requirements.txt (line 2))
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting rank-bm25==0.2.2 (from -r requirements.txt (line 3))
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting transformers==4.57.3 (from -r requirements.txt (line 4))
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.9 MB/s eta 0:00:00
# Collecting accelerate==1.12.0 (from -r requirements.txt (line 5))
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentence-transformers==5.1.0 (from -r requirements.txt (line 6))
#   Downloading sentence_transformers-5.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client==1.18.0->-r requirements.txt (line 1)) (1.80.0)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from qdrant-client==1.18.0->-r requirements.txt (line 1)) (2.4.6)
# Collecting portalocker<4.0,>=2.7.0 (from qdrant-client==1.18.0->-r requirements.txt (line 1))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from qdrant-client==1.18.0->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /usr/local/lib/python3.12/dist-packages (from qdrant-client==1.18.0->-r requirements.txt (line 1)) (2.12.3)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.12/dist-packages (from qdrant-client==1.18.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyvi==0.1.1->-r requirements.txt (line 2)) (1.6.1)
# Collecting sklearn-crfsuite (from pyvi==0.1.1->-r requirements.txt (line 2))
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers==4.57.3->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.3->-r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.12.0->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==1.12.0->-r requirements.txt (line 5)) (2.10.0+cu128)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==5.1.0->-r requirements.txt (line 6)) (1.16.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==5.1.0->-r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==5.1.0->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.3->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers==4.57.3->-r requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client==1.18.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client==1.18.0->-r requirements.txt (line 1)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client==1.18.0->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (3.1.6)
# Collecting cuda-bindings==12.9.4 (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5))
#   Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.57.3->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi==0.1.1->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyvi==0.1.1->-r requirements.txt (line 2)) (3.6.0)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite->pyvi==0.1.1->-r requirements.txt (line 2))
#   Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: tabulate>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from sklearn-crfsuite->pyvi==0.1.1->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client==1.18.0->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate==1.12.0->-r requirements.txt (line 5)) (3.0.3)
# Downloading qdrant_client-1.18.0-py3-none-any.whl (398 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 11.0 MB/s eta 0:00:00
# Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 87.1 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 102.6 MB/s eta 0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 27.3 MB/s eta 0:00:00
# Downloading sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.4/483.4 kB 34.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 35.7 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Downloading cuda_bindings-12.9.4-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 103.3 MB/s eta 0:00:00
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.2 MB/s eta 0:00:00
# Installing collected packages: rank-bm25, python-crfsuite, portalocker, cuda-bindings, huggingface-hub, sklearn-crfsuite, transformers, qdrant-client, pyvi, accelerate, sentence-transformers
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 13.2.0
#     Uninstalling cuda-bindings-13.2.0:
#       Successfully uninstalled cuda-bindings-13.2.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.10.1
#     Uninstalling huggingface_hub-1.10.1:
#       Successfully uninstalled huggingface_hub-1.10.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.13.0
#     Uninstalling accelerate-1.13.0:
#       Successfully uninstalled accelerate-1.13.0
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.4.0
#     Uninstalling sentence-transformers-5.4.0:
#       Successfully uninstalled sentence-transformers-5.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Successfully installed accelerate-1.12.0 cuda-bindings-12.9.4 huggingface-hub-0.36.2 portalocker-3.2.0 python-crfsuite-0.9.12 pyvi-0.1.1 qdrant-client-1.18.0 rank-bm25-0.2.2 sentence-transformers-5.1.0 sklearn-crfsuite-0.5.0 transformers-4.57.3

# %%
from pipeline_choose import qa_pipeline
# Out:
# 2026-06-20 06:40:05.453831: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781937605.626842      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781937605.676661      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781937606.076925      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781937606.076970      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781937606.076973      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781937606.076975      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/283 [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:You are trying to use a model that was created with Sentence Transformers version 5.2.3, but you're currently using version 5.1.0. This might cause unexpected behavior or errors. In that case, try to update to the latest version.
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/741 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/354 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.8M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/312 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/huynhdat543/VietNamese_law_rerank_v1:
# - configuration.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/huynhdat543/VietNamese_law_rerank_v1:
# - modeling.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# [RERANK] FP16 enabled on GPU
# config.json:   0%|          | 0.00/756 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# [RERANK] FP16 enabled on GPU
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/790 [00:00<?, ?B/s]
# checkpoint-6795/model.safetensors:   0%|          | 0.00/709M [00:00<?, ?B/s]
# Device set to use cuda:0
# [EXTRACT] Model loaded
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
result = qa_pipeline(
    user_query="Cơ quan nào chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về viễn thông?",
    answers = """['Bộ Thông tin và Truyền thông.', 'Bộ Công Thương.', 'Bộ Khoa học và Công nghệ.', 'Bộ Công an.']""",

    # rewrite
    use_rewrite = True,
    num_rewrites = 3,

    # retrieval
    retrieval_top_k = 100,

    # rewrite rrf
    use_rewrite_rrf = True,
    rewrite_rrf_top_n = 50,

    # rerank
    use_rerank = True,

    # dual rerank
    use_dual_rerank = True,

    rerank_top_k = 10,

    # extract
    use_extract = True,

    # print result
    print_result = True
)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [REWRITE] 4 queries
# [HYBRID SEARCH] 4 done
# [REWRITE RRF] 50 docs
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# [RERANK] dual done 10
# [EXTRACT] done
# [LLM] done
#
#
# ==================================================
#
#
# QUERY: Cơ quan nào chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về viễn thông?
# REWRITES: ['Cơ quan nào chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về viễn thông?', 'Cơ quan nào có trách nhiệm trong việc quản lý nhà nước về lĩnh vực viễn thông trước Chính phủ?', 'Quyền hạn và trách nhiệm của cơ quan nào trong việc quản lý viễn thông trước Chính phủ?', 'Chánh phủ giao cho cơ quan nào chịu trách nhiệm quản lý nhà nước về lĩnh vực viễn thông?']
# RESULT:
# ------------------------------
# Rank: 1
# ID: 20_2023_QH15_D50_K2
# Hybrid_RRF: 0.013797468354430378
# Rewrite_RRF: 0.054321488696488694
# Rerank: None
# Rerank_ViNLI: 0.69677734375
# Rerank_Combine: 0.99755859375
# Rerank_RRF: 0.03278688524590164
# Extract: 0.3052554130554199
# Text: Trách nhiệm quản lý nhà nước về giao dịch điện tử Bộ Thông tin và Truyền thông là cơ quan đầu mối chịu trách nhiệm trước Chính phủ trong việc chủ trì, phối hợp với các Bộ, cơ quan ngang Bộ thực hiện quản lý nhà nước về giao dịch điện tử.
# Text_tokenized: Trách_nhiệm quản_lý nhà_nước về giao_dịch điện_tử Bộ Thông_tin và Truyền_thông là cơ_quan đầu_mối chịu trách_nhiệm trước Chính_phủ trong việc chủ_trì , phối_hợp với các Bộ , cơ_quan ngang Bộ thực_hiện quản_lý nhà_nước về giao_dịch điện_tử .
# Extract Text: cơ_quan đầu_mối
# ------------------------------
# Rank: 2
# ID: 24_2023_QH15_D69_K4
# Hybrid_RRF: 0.011869065467266366
# Rewrite_RRF: 0.06259734084890786
# Rerank: None
# Rerank_ViNLI: 0.60986328125
# Rerank_Combine: 0.9736328125
# Rerank_RRF: 0.03149801587301587
# Extract: 0.9998276233673096
# Text: Trách nhiệm quản lý nhà nước về viễn thông Bộ, cơ quan ngang Bộ, trong phạm vi nhiệm vụ, quyền hạn của mình, có trách nhiệm phối hợp với Bộ Thông tin và Truyền thông thực hiện quản lý nhà nước về viễn thông.
# Text_tokenized: Trách_nhiệm quản_lý nhà_nước về viễn_thông Bộ , cơ_quan ngang Bộ , trong phạm_vi nhiệm_vụ , quyền_hạn của mình , có trách_nhiệm phối_hợp với Bộ Thông_tin và Truyền_thông thực_hiện quản_lý nhà_nước về viễn_thông .
# Extract Text:
# ------------------------------
# Rank: 3
# ID: 116_2025_QH15_D39_K3_a
# Hybrid_RRF: 0.012345679012345678
# Rewrite_RRF: 0.04235818129002808
# Rerank: None
# Rerank_ViNLI: 0.58544921875
# Rerank_Combine: 0.9775390625
# Rerank_RRF: 0.03057889822595705
# Extract: 0.9984054565429688
# Text: Bộ Quốc phòng chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về an ninh mạng thuộc phạm vi quản lý như sau: Trách nhiệm quản lý nhà nước về an ninh mạng Ban hành hoặc trình cơ quan nhà nước có thẩm quyền ban hành văn bản quy phạm pháp luật về an ninh mạng trong phạm vi quản lý;
# Text_tokenized: Bộ Quốc_phòng chịu trách_nhiệm trước Chính_phủ thực_hiện quản_lý nhà_nước về an_ninh mạng thuộc phạm_vi quản_lý như sau : Trách_nhiệm quản_lý nhà_nước về an_ninh mạng Ban_hành hoặc trình cơ_quan nhà_nước có thẩm_quyền ban_hành_văn_bản quy_phạm_pháp_luật về an_ninh mạng trong phạm_vi quản_lý ;
# Extract Text:
# ------------------------------
# Rank: 4
# ID: 24_2023_QH15_D69_K2
# Hybrid_RRF: 0.015371513732169469
# Rewrite_RRF: 0.06478053939714437
# Rerank: None
# Rerank_ViNLI: 0.54150390625
# Rerank_Combine: 0.99072265625
# Rerank_RRF: 0.030017921146953404
# Extract: 0.534151554107666
# Text: Trách nhiệm quản lý nhà nước về viễn thông Bộ Thông tin và Truyền thông là cơ quan đầu mối giúp Chính phủ thực hiện quản lý nhà nước về viễn thông.
# Text_tokenized: Trách_nhiệm quản_lý nhà_nước về viễn_thông Bộ Thông_tin và Truyền_thông là cơ_quan đầu_mối giúp Chính_phủ thực_hiện quản_lý nhà_nước về viễn_thông .
# Extract Text: Bộ Thông_tin và Truyền_thông
# ------------------------------
# Rank: 5
# ID: 116_2025_QH15_D39_K3_c
# Hybrid_RRF: 0.010205453149001537
# Rewrite_RRF: 0.03619521777416514
# Rerank: None
# Rerank_ViNLI: 0.58740234375
# Rerank_Combine: 0.95361328125
# Rerank_RRF: 0.029850746268656716
# Extract: 0.9978119134902954
# Text: Bộ Quốc phòng chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về an ninh mạng thuộc phạm vi quản lý như sau: Trách nhiệm quản lý nhà nước về an ninh mạng Phòng ngừa, đấu tranh với các hoạt động sử dụng không gian mạng xâm phạm an ninh quốc gia trong phạm vi quản lý;
# Text_tokenized: Bộ Quốc_phòng chịu trách_nhiệm trước Chính_phủ thực_hiện quản_lý nhà_nước về an_ninh mạng thuộc phạm_vi quản_lý như sau : Trách_nhiệm quản_lý nhà_nước về an_ninh mạng Phòng_ngừa , đấu_tranh với các hoạt_động sử_dụng không_gian mạng xâm_phạm an_ninh quốc_gia trong phạm_vi quản_lý ;
# Extract Text:
# ------------------------------
# Rank: 6
# ID: 07_2026_QH16_D57_K2
# Hybrid_RRF: 0.01282170542635659
# Rewrite_RRF: 0.02904040404040404
# Rerank: None
# Rerank_ViNLI: 0.59814453125
# Rerank_Combine: 0.82958984375
# Rerank_RRF: 0.02967032967032967
# Extract: 0.5731978416442871
# Text: Thẩm quyền quản lý nhà nước về tín ngưỡng, tôn giáo Bộ Dân tộc và Tôn giáo chịu trách nhiệm trước Chính phủ trong việc thực hiện quản lý nhà nước về tín ngưỡng, tôn giáo.
# Text_tokenized: Thẩm_quyền quản_lý nhà_nước về tín_ngưỡng , tôn_giáo Bộ Dân_tộc và Tôn_giáo chịu trách_nhiệm trước Chính_phủ trong việc thực_hiện quản_lý nhà_nước về tín_ngưỡng , tôn_giáo .
# Extract Text: Bộ Dân_tộc và Tôn_giáo
# ------------------------------
# Rank: 7
# ID: 60_2024_QH15_D8_K2_c
# Hybrid_RRF: 0.008288770053475935
# Rewrite_RRF: 0.035648864809081526
# Rerank: None
# Rerank_ViNLI: 0.58984375
# Rerank_Combine: 0.8984375
# Rerank_RRF: 0.02964426877470356
# Extract: 0.9966047406196594
# Text: Trách nhiệm quản lý nhà nước về dữ liệu được quy định như sau: Quản lý nhà nước về dữ liệu Bộ Quốc phòng chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về dữ liệu thuộc phạm vi quản lý.
# Bộ trưởng Bộ Quốc phòng chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về dữ liệu cơ yếu thuộc phạm vi quản lý theo quy định của pháp luật về cơ yếu;
# Text_tokenized: Trách_nhiệm quản_lý nhà_nước về dữ_liệu được quy_định như sau : Quản_lý nhà_nước về dữ_liệu Bộ Quốc_phòng chịu trách_nhiệm trước Chính_phủ thực_hiện quản_lý nhà_nước về dữ_liệu thuộc phạm_vi quản_lý .
#  Bộ_trưởng Bộ Quốc_phòng chịu trách_nhiệm trước Chính_phủ thực_hiện quản_lý nhà_nước về dữ_liệu cơ_yếu thuộc phạm_vi quản_lý theo quy_định của pháp_luật về cơ_yếu ;
# Extract Text:
# ------------------------------
# Rank: 8
# ID: 24_2023_QH15_D59_K1_c
# Hybrid_RRF: 0.00789373400838369
# Rewrite_RRF: 0.028814094807883626
# Rerank: None
# Rerank_ViNLI: 0.599609375
# Rerank_Combine: 0.71435546875
# Rerank_RRF: 0.029138513513513514
# Extract: 0.9925298094749451
# Text: Bộ Thông tin và Truyền thông có trách nhiệm sau đây: Quản lý giá dịch vụ viễn thông Chủ động phối hợp với Bộ Công Thương thực hiện quản lý cạnh tranh trong lĩnh vực viễn thông theo quy định của pháp luật về cạnh tranh; phối hợp quản lý hoạt động khuyến mại trong cung cấp dịch vụ viễn thông;
# Text_tokenized: Bộ Thông_tin và Truyền_thông có trách_nhiệm sau đây : Quản_lý giá dịch_vụ viễn_thông Chủ_động phối_hợp với Bộ Công_Thương thực_hiện quản_lý cạnh_tranh trong lĩnh_vực viễn_thông theo quy_định của pháp_luật về cạnh_tranh ; phối_hợp quản_lý hoạt_động khuyến_mại trong cung_cấp dịch_vụ viễn_thông ;
# Extract Text:
# ------------------------------
# Rank: 9
# ID: 103_2016_QH13_D7_K2
# Hybrid_RRF: 0.015687263556116014
# Rewrite_RRF: 0.047891458495966696
# Rerank: None
# Rerank_ViNLI: 0.61279296875
# Rerank_Combine: 0.67578125
# Rerank_RRF: 0.028949545078577336
# Extract: 0.6174988150596619
# Text: Cơ quan quản lý nhà nước về báo chí Bộ Thông tin và Truyền thông chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về báo chí.
# Text_tokenized: Cơ_quan quản_lý nhà_nước về báo_chí Bộ Thông_tin và Truyền_thông chịu trách_nhiệm trước Chính_phủ thực_hiện quản_lý nhà_nước về báo_chí .
# Extract Text: Cơ_quan quản_lý nhà_nước về báo_chí Bộ Thông_tin và Truyền_thông
# ------------------------------
# Rank: 10
# ID: 24_2023_QH15_D69_K3
# Hybrid_RRF: 0.01129032258064516
# Rewrite_RRF: 0.05853035853035853
# Rerank: None
# Rerank_ViNLI: 0.541015625
# Rerank_Combine: 0.97021484375
# Rerank_RRF: 0.028665028665028666
# Extract: 0.9996610283851624
# Text: Trách nhiệm quản lý nhà nước về viễn thông Bộ Quốc phòng, Bộ Công an, trong phạm vi nhiệm vụ, quyền hạn của mình, thực hiện quản lý mạng viễn thông dùng riêng phục vụ quốc phòng, an ninh; Bộ trưởng Bộ Quốc phòng quản lý mạng viễn thông dùng riêng phục vụ cơ yếu.
# Text_tokenized: Trách_nhiệm quản_lý nhà_nước về viễn_thông Bộ Quốc_phòng , Bộ Công_an , trong phạm_vi nhiệm_vụ , quyền_hạn của mình , thực_hiện quản_lý mạng viễn_thông dùng riêng phục_vụ quốc_phòng , an_ninh ; Bộ_trưởng Bộ Quốc_phòng quản_lý mạng viễn_thông dùng riêng phục_vụ cơ_yếu .
# Extract Text:

# %%
# print(result["answer"])
print(result)
# Out:
# 0

# %%
# import gc
# import torch

df_groundtruth = pd.read_csv("/kaggle/input/datasets/tihunhpht/se365-gte-bge-v2/tracnghiem_groundtruth/tracnghiem_groundtruth_NoDungSai.csv")

predictions = []

for _, row in tqdm(df_groundtruth.iterrows(), total=len(df_groundtruth), desc="Predicting", position=0, leave=True):

    pred = qa_pipeline(
    user_query= row["question"],
    answers = row["answers"],

    # rewrite
    use_rewrite = True,
    num_rewrites = 3,

    # retrieval
    retrieval_top_k = 100,

    # rewrite rrf
    use_rewrite_rrf = True,
    rewrite_rrf_top_n = 50,

    # rerank
    use_rerank = True,

    # dual rerank
    use_dual_rerank = True,

    rerank_top_k = 10,

    # extract
    use_extract = False,

    # print result
    print_result = False
)

    predictions.append(pred)

    # gc.collect()
    # torch.cuda.empty_cache()

df_groundtruth["pred_label"] = predictions
# Out:
# Predicting: 100%|██████████| 3025/3025 [9:03:40<00:00, 10.78s/it]

# %%
output_path = "/kaggle/working/groundtruth_inference.csv"

df_groundtruth.to_csv(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Saved to: /kaggle/working/groundtruth_inference.csv

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# df_groundtruth = pd.read_csv("/content/groundtruth_inference.csv")

y_true = df_groundtruth["correct_answer"]
y_pred = df_groundtruth["pred_label"]

accuracy_score = accuracy_score(y_true, y_pred)
precision_score = precision_score(y_true, y_pred, average="macro")
recall_score = recall_score(y_true, y_pred, average="macro")
f1_score = f1_score(y_true, y_pred, average="macro")


print("\ntracnghiem_groundtruth inference:")
print("Accuracy Score:", accuracy_score)
print("Precision Score:", precision_score)
print("Recall Score:", recall_score)
print("F1 Score:", f1_score)
# Out:
# tracnghiem_groundtruth inference:
# Accuracy Score: 0.5735537190082645
# Precision Score: 0.5809499896316008
# Recall Score: 0.5845454245265349
# F1 Score: 0.5788475884250421
